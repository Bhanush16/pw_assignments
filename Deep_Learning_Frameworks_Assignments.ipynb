# %% [markdown]
# ### **1. What is TensorFlow 2.0, and how is it different from TensorFlow 1.x?**
#
# **Answer:**
# TensorFlow 2.0 is an improved version of TensorFlow that emphasizes **simplicity, ease of use, and eager execution**.
# **Differences from TensorFlow 1.x:**
#
# * Eager execution enabled by default
# * Keras integrated as the high-level API
# * No need for sessions (`tf.Session`)
# * Cleaner and more Pythonic code
# * Better debugging and performance
#
# ---
#
# ### **2. How do you install TensorFlow 2.0?**
#
# **Answer:**
#
# ```bash
# pip install tensorflow
# ```
#
# For GPU support:
#
# ```bash
# pip install tensorflow-gpu
# ```
#
# ---
#
# ### **3. What is the primary function of `tf.function` in TensorFlow 2.0?**
#
# **Answer:**
# `tf.function` converts Python functions into **optimized TensorFlow graphs**, improving performance while keeping code readable.
#
# ---
#
# ### **4. What is the purpose of the Model class in TensorFlow 2.0?**
#
# **Answer:**
# The `Model` class is used to:
#
# * Define neural network architectures
# * Train, evaluate, and predict models
# * Customize training logic when needed
#
# ---
#
# ### **5. How do you create a neural network using TensorFlow 2.0?**
#
# **Answer:**
#
# ```python
# import tensorflow as tf
#
# model = tf.keras.Sequential([
#     tf.keras.layers.Dense(64, activation='relu'),
#     tf.keras.layers.Dense(1)
# ])
# ```
#
# ---
#
# ### **6. What is the importance of Tensor Space in TensorFlow 2?**
#
# **Answer:**
# Tensor Space refers to the **multidimensional structure** where tensors exist, enabling efficient mathematical operations essential for deep learning computations.
#
# ---
#
# ### **7. How can TensorBoard be integrated with TensorFlow 2.0?**
#
# **Answer:**
#
# ```python
# tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir="logs/")
# model.fit(X, y, callbacks=[tensorboard_cb])
# ```
#
# Then run:
#
# ```bash
# tensorboard --logdir=logs
# ```
#
# ---
#
# ### **8. What is the purpose of TensorFlow Playground?**
#
# **Answer:**
# TensorFlow Playground is an **interactive web tool** for visualizing and understanding neural networks, activations, and learning behavior.
#
# ---
#
# ### **9. What is Netron, and how is it useful for deep learning models?**
#
# **Answer:**
# Netron is a **model visualization tool** that displays network architecture, layers, and parameters for models from TensorFlow, PyTorch, ONNX, etc.
#
# ---
#
# ### **10. What is the difference between TensorFlow and PyTorch?**
#
# **Answer:**
#
# | TensorFlow              | PyTorch             |
# | ----------------------- | ------------------- |
# | Static + dynamic graphs | Dynamic graphs      |
# | Better for production   | Better for research |
# | Uses Keras              | Uses native Python  |
# | More enterprise tools   | Easier debugging    |
#
# ---
#
# ### **11. How do you install PyTorch?**
#
# **Answer:**
#
# ```bash
# pip install torch torchvision torchaudio
# ```
#
# ---
#
# ### **12. What is the basic structure of a PyTorch neural network?**
#
# **Answer:**
#
# ```python
# import torch.nn as nn
#
# class Net(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc = nn.Linear(10, 1)
#
#     def forward(self, x):
#         return self.fc(x)
# ```
#
# ---
#
# ### **13. What is the significance of tensors in PyTorch?**
#
# **Answer:**
# Tensors are **multi-dimensional arrays** used to store data and gradients, and they support GPU acceleration for fast computation.
#
# ---
#
# ### **14. What is the difference between `torch.Tensor` and `torch.cuda.Tensor`?**
#
# **Answer:**
#
# * `torch.Tensor` → Stored on CPU
# * `torch.cuda.Tensor` → Stored on GPU for faster computation
#
# ---
#
# ### **15. What is the purpose of the `torch.optim` module in PyTorch?**
#
# **Answer:**
# It provides **optimization algorithms** like SGD, Adam, and RMSprop to update model parameters during training.
#
# ---
#
# ### **16. What are some common activation functions used in neural networks?**
#
# **Answer:**
#
# * ReLU
# * Sigmoid
# * Tanh
# * Softmax
# * Leaky ReLU
#
# ---
#
# ### **17. What is the difference between `torch.nn.Module` and `torch.nn.Sequential`?**
#
# **Answer:**
#
# * `nn.Module` → Flexible, custom networks
# * `nn.Sequential` → Simple stack of layers without custom logic
#
# ---
#
# ### **18. How can you monitor training progress in TensorFlow 2.0?**
#
# **Answer:**
# Using:
#
# * TensorBoard
# * Training logs from `model.fit()`
# * Callbacks like EarlyStopping and ModelCheckpoint
#
# ---
#
# ### **19. How does the Keras API fit into TensorFlow 2.0?**
#
# **Answer:**
# Keras is the **official high-level API** in TensorFlow 2.0, simplifying model building, training, and deployment.
#
# ---
#
# ### **20. What is an example of a deep learning project using TensorFlow 2.0?**
#
# **Answer:**
#
# * Image classification using CNNs
# * Face recognition
# * Sentiment analysis
# * Handwritten digit recognition (MNIST)
#
# ---
#
# ### **21. What is the main advantage of using pre-trained models in TensorFlow and PyTorch?**
#
# **Answer:**
# Pre-trained models:
#
# * Reduce training time
# * Require less data
# * Improve accuracy
# * Enable transfer learning
#
# ---

# %%
# Q1: How do you install and verify that TensorFlow 2.0 was installed successfully?

# Installation (run in terminal or command prompt)
# pip install tensorflow

# Verification
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
# Q2: How can you define a simple function in TensorFlow 2.0 to perform addition?

import tensorflow as tf

@tf.function
def add(a, b):
    return a + b

result = add(3, 5)
print(result)
# Out:
# tf.Tensor(8, shape=(), dtype=int32)

# %%
# Q3: How can you create a simple neural network in TensorFlow 2.0 with one hidden layer?

import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(10,)),
    tf.keras.layers.Dense(1)
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 385 (1.50 KB)
#  Trainable params: 385 (1.50 KB)
# ...

# %%
# Q4: How can you visualize the training progress using TensorFlow and Matplotlib?

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

X = np.random.rand(100, 1)
y = 3 * X + 2

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=(1,))
])

model.compile(optimizer='adam', loss='mse')

history = model.fit(X, y, epochs=20, verbose=0)

plt.plot(history.history['loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.show()

# %%
# Q5: How do you install PyTorch and verify the PyTorch installation?

# Installation (run in terminal)
# pip install torch torchvision torchaudio

# Verification
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.9.0+cpu
# False

# %%
# Q6: How do you create a simple neural network in PyTorch?

import torch
import torch.nn as nn

class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(10, 32)
        self.fc2 = nn.Linear(32, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        return self.fc2(x)

model = SimpleNet()
print(model)
# Out:
# SimpleNet(
#   (fc1): Linear(in_features=10, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )
